# %%
import os

# %%
#!wget https://github.com/GuruChandra/DataSet/blob/main/creditcard.csv.zip
# !wget https://github.com/GuruChandra/DataSet/raw/refs/heads/main/creditcard.csv.zip
# Out:
# --2025-03-25 14:42:23--  https://github.com/GuruChandra/DataSet/raw/refs/heads/main/creditcard.csv.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/GuruChandra/DataSet/refs/heads/main/creditcard.csv.zip [following]
# --2025-03-25 14:42:23--  https://raw.githubusercontent.com/GuruChandra/DataSet/refs/heads/main/creditcard.csv.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 69155672 (66M) [application/zip]
# Saving to: ‘creditcard.csv.zip’
#
# creditcard.csv.zip  100%[===================>]  65.95M  66.3MB/s    in 1.0s
#
# ...

# %%
# !unzip creditcard.csv.zip
#%pwd
# Out:
# Archive:  creditcard.csv.zip
#   inflating: creditcard.csv

# %%
#os.chdir('../')

# %%
ls
# Out:
# creditcard.csv  creditcard.csv.zip  sample_data/

# %%
from zipfile import ZipFile
with ZipFile('creditcard.csv.zip','r') as zf:
    zf.extractall()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib
# Out:
# Using matplotlib backend: <object object at 0x7cef3cc06c30>

# %%
#!pip install --upgrade numpy pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('creditcard.csv')
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.hist(bins=30,figsize=(30,30))
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
# ...

# %%
from sklearn.preprocessing import RobustScaler
newdf = df.copy()
newdf['Amount'] = RobustScaler().fit_transform(newdf['Amount'].to_numpy().reshape(-1,1))
time = newdf['Time']
newdf['Time'] = (time-time.min())/(time.max()-time.min())

# %%
newdf['Time'].describe()
# Out:
# count    284807.000000
# mean          0.548717
# std           0.274828
# min           0.000000
# 25%           0.313681
# 50%           0.490138
# 75%           0.806290
# max           1.000000
# Name: Time, dtype: float64

# %%
new_df = newdf.sample(frac=1, random_state=1)
new_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  0.693938 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467  0.453377 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900  0.476770 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513   0.183556 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700  0.468326  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
# ...          ...       ...       ...       ...       ...       ...       ...
# 21440   0.183261 -2.986845 -8.663978 -1.910863  0.664058 -3.934875  0.861269
# 117583  0.432480  0.937083 -0.849673  0.524186 -0.020031 -0.606327  0.692302
# 73349   0.318852 -1.149963  1.696462  1.637114  2.658991 -0.021502  0.192287
# 267336  0.941757  1.754554 -0.699398 -0.076332  0.443915 -0.672082  0.389061
# 128037  0.454743 -0.707635  0.493302  2.648089  1.064807 -0.680271  1.183838
#
# ...

# %%
train, test, val = new_df[:240000], new_df[240000:262000], new_df[262000:]
train['Class'].value_counts(), test['Class'].value_counts(), val['Class'].value_counts()
# Out:
# (Class
#  0    239589
#  1       411
#  Name: count, dtype: int64,
#  Class
#  0    21955
#  1       45
#  Name: count, dtype: int64,
#  Class
#  0    22771
#  1       36
#  Name: count, dtype: int64)

# %%
type(train)
# Out:
# pandas.core.frame.DataFrame

# %%
train_np, test_np, val_np = train.to_numpy(), test.to_numpy(), val.to_numpy()
train_np.shape, test_np.shape, val_np.shape
# Out:
# ((240000, 31), (22000, 31), (22807, 31))

# %%
x_train, y_train = train_np[:,:-1], train_np[:,-1]
x_test, y_test = test_np[:,:-1], test_np[:,-1]
x_val, y_val = val_np[:,:-1], val_np[:,-1]
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((240000, 30), (240000,), (22000, 30), (22000,))

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train,y_train)
logistic_model.score(x_train, y_train)
# Out:
# 0.9992375

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, logistic_model.predict(x_val), target_names=['Not fraud','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not fraud       1.00      1.00      1.00     22771
#        Fraud       0.83      0.56      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.92      0.78      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %% [markdown]
# #recall - how many are correctly predicted - Recall=
# TP/(TP+FN)
# ​
# is measure of false negative - we want it high
# #precision -TP/(TP+FP) how many are actually correct
#
# #accuray -

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(max_depth=2, n_jobs=1)
rf.fit(x_train,y_train)
print(classification_report(y_val, rf.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.80      0.44      0.57        36
#
#     accuracy                           1.00     22807
#    macro avg       0.90      0.72      0.79     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=1.0, max_depth=1, n_estimators=50,
#                            random_state=0)

# %%
print(classification_report(y_val, gbc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     22771
#        Fraud       0.67      0.67      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.83      0.83      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(class_weight='balanced')
svc.fit(x_train, y_train)
# Out:
# LinearSVC(class_weight='balanced')

# %%
print(classification_report(y_val, svc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.98      0.99     22771
#        Fraud       0.07      0.97      0.14        36
#
#     accuracy                           0.98     22807
#    macro avg       0.54      0.98      0.56     22807
# weighted avg       1.00      0.98      0.99     22807

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169876  0.693938 -0.611712 -0.769705 -0.149759 -0.224877  2.028577 -2.019887
# 127467  0.453377 -0.814682  1.319219  1.329415  0.027273 -0.284871 -0.653985
# 137900  0.476770 -0.318193  1.118618  0.969864 -0.127052  0.569563 -0.532484
# 21513   0.183556 -1.328271  1.018378  1.775426 -1.574193 -0.117696 -0.457733
# 134700  0.468326  1.276712  0.617120 -0.578014  0.879173  0.061706 -1.472002
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 169876  0.292491 -0.523020  0.358468  ... -0.075208  0.045536  0.380739
# 127467  0.321552  0.435975 -0.704298  ... -0.128619 -0.368565  0.090660
# 137900  0.706252 -0.064966 -0.463271  ... -0.305402 -0.774704 -0.123884
# 21513   0.681867 -0.031641  0.383872  ... -0.220815 -0.419013 -0.239197
# 134700  0.373692 -0.287204 -0.084482  ... -0.160161 -0.430404 -0.076738
#
# ...

# %%
fraud = new_df.query('Class == 1')
not_fraud = new_df.query('Class == 0')

# %%
fraud['Class'].value_counts()
# Out:
# Class
# 1    492
# Name: count, dtype: int64

# %%
balanced_df = pd.concat([fraud, not_fraud.sample(len(fraud), random_state=100)])
balanced_df['Class'].value_counts()
# Out:
# Class
# 1    492
# 0    492
# Name: count, dtype: int64

# %%
balanced_df  = balanced_df.sample(frac=1, random_state=1)

# %%
balanced_df_np = balanced_df.to_numpy()
x_train_b, y_train_b = balanced_df_np[:700, :-1], balanced_df_np[:700,-1].astype(int)
x_test_b, y_test_b = balanced_df_np[700:842, :-1], balanced_df_np[700:842,-1].astype(int)
x_val_b, y_val_b = balanced_df_np[842:, :-1], balanced_df_np[842:,-1].astype(int)

# %%
len(y_train_b[y_train_b==1])
# Out:
# 353

# %%
len(y_val_b[y_val_b==1])
# Out:
# 70

# %%
np.min(y_val_b),np.max(y_val_b)
# Out:
# (np.int64(0), np.int64(1))

# %%
balanced_df['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
np.min(y_train_b), np.max(y_train_b)
# Out:
# (np.int64(0), np.int64(1))

# %%
logistic_model = LogisticRegression()
logistic_model.fit(x_train_b,y_train_b)
logistic_model.score(x_train_b, y_train_b)
# Out:
# 0.9471428571428572

# %%
print(classification_report(y_train,logistic_model.predict(x_train),target_names=['Not Fraud','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.97      0.99    239589
#        Fraud       0.06      0.92      0.11       411
#
#     accuracy                           0.97    240000
#    macro avg       0.53      0.95      0.55    240000
# weighted avg       1.00      0.97      0.99    240000

# %%
from sklearn.ensemble import  RandomForestClassifier

rf = RandomForestClassifier(max_depth=10,n_estimators=100,class_weight="balanced",random_state=42)
rf.fit(x_train_b,y_train_b)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=10, random_state=42)

# %%
print(classification_report(y_val,rf.predict(x_val),target_names=['Not Fraud','Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.97      0.99     22771
#        Fraud       0.05      1.00      0.10        36
#
#     accuracy                           0.97     22807
#    macro avg       0.53      0.99      0.54     22807
# weighted avg       1.00      0.97      0.98     22807

# %% [markdown]
# ### USING RESAMPLING (SMOTE undersampling, oversampling)

# %%
from imblearn.over_sampling import  SMOTE
smote = SMOTE(sampling_strategy=0.05, random_state=42)

# %%
x_train_resampled, y_train_resampled = smote.fit_resample(x_train,y_train)

# %%
x_train_resampled.shape
# Out:
# (251568, 30)

# %%
logistic_model.fit(x_train_resampled, y_train_resampled)
# Out:
# LogisticRegression()

# %%
print(classification_report(y_val, logistic_model.predict(x_val), target_names=["Not fraud", "Fraud"]))
# Out:
#               precision    recall  f1-score   support
#
#    Not fraud       1.00      1.00      1.00     22771
#        Fraud       0.56      0.83      0.67        36
#
#     accuracy                           1.00     22807
#    macro avg       0.78      0.92      0.83     22807
# weighted avg       1.00      1.00      1.00     22807

# %%
rf = RandomForestClassifier(n_estimators=200,max_depth=20)
rf.fit(x_train_resampled,y_train_resampled)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200)

# %%
print(classification_report(y_val, rf.predict(x_val), target_names=["Not fraud", "Fraud"]))
# Out:
#               precision    recall  f1-score   support
#
#    Not fraud       1.00      1.00      1.00     22771
#        Fraud       0.83      0.81      0.82        36
#
#     accuracy                           1.00     22807
#    macro avg       0.91      0.90      0.91     22807
# weighted avg       1.00      1.00      1.00     22807
